# %%
import numpy as np
import pandas as pd
from utils import process_tweet, build_freqs

# %%
#### READING FILE FROM CSV ####

df = pd.read_csv("/home/bhaskar/Downloads/Coursera_NLP/hackathon_av/train_2kmZucJ.csv",header='infer')
df.head()
# Out:
#    id  label                                              tweet
# 0   1      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1   2      0  Finally a transparant silicon case ^^ Thanks t...
# 2   3      0  We love this! Would you go? #talk #makememorie...
# 3   4      0  I'm wired I know I'm George I was made that wa...
# 4   5      1  What amazing service! Apple won't even talk to...

# %%
df.drop(['id'],inplace = True,axis=1)
df.head()
# Out:
#    label                                              tweet
# 0      0  #fingerprint #Pregnancy Test https://goo.gl/h1...
# 1      0  Finally a transparant silicon case ^^ Thanks t...
# 2      0  We love this! Would you go? #talk #makememorie...
# 3      0  I'm wired I know I'm George I was made that wa...
# 4      1  What amazing service! Apple won't even talk to...

# %%
train_x = df.tweet.values
train_y = df.label.values

type(train_x)
# Out:
# numpy.ndarray

# %%
# UNQ_C1 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def sigmoid(z): 
    '''
    Input:
        z: is the input (can be a scalar or an array)
    Output:
        h: the sigmoid of z
    '''
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # calculate the sigmoid of z
    h = 1/(1+ np.exp(-z))
    ### END CODE HERE ###
    
    return h


# Testing your function 
if (sigmoid(0) == 0.5):
    print('SUCCESS!')
else:
    print('Oops!')

if (sigmoid(4.92) == 0.9927537604041685):
    print('CORRECT!')
else:
    print('Oops again!')
# Out:
# SUCCESS!
# CORRECT!

# %%
freqs = build_freqs(train_x,train_y)

# check the output
print("type(freqs) = " + str(type(freqs)))
print("len(freqs) = " + str(len(freqs.keys())))
# Out:
# type(freqs) = <class 'dict'>
# len(freqs) = 16397

# %%
freqs
# Out:
# {('fingerprint', 0): 4,
#  ('pregnanc', 0): 1,
#  ('test', 0): 11,
#  ('final', 0): 176,
#  ('transpar', 0): 5,
#  ('silicon', 0): 4,
#  ('case', 0): 297,
#  ('thank', 0): 183,
#  ('uncl', 0): 4,
#  (':)', 0): 183,
#  ('yay', 0): 64,
#  ('soni', 0): 699,
#  ('xperia', 0): 57,
#  ('sonyexperia', 0): 2,
#  ('…', 0): 1368,
#  ('love', 0): 450,
#  ('would', 0): 95,
#  ('go', 0): 100,
#  ('talk', 0): 19,
#  ('makememori', 0): 1,
#  ('unplug', 0): 2,
#  ('relax', 0): 38,
#  ('iphon', 0): 2925,
#  ('smartphon', 0): 75,
#  ('wifi', 0): 32,
#  ('connect', 0): 9,
#  ('...', 0): 721,
#  ("i'm", 0): 147,
#  ('wire', 0): 5,
#  ('know', 0): 61,
#  ('georg', 0): 1,
#  ('made', 0): 46,
#  ('way', 0): 35,
#  (';)', 0): 28,
#  ('cute', 0): 262,
#  ('daventri', 0): 1,
#  ('home', 0): 116,
#  ('amaz', 1): 7,
#  ('servic', 1): 25,
#  ('appl', 1): 1246,
#  ('even', 1): 56,
#  ('talk', 1): 6,
#  ('question', 1): 7,
#  ('unless', 1): 3,
#  ('pay', 1): 37,
#  ('95', 1): 2,
#  ('stupid', 1): 56,
#  ('support', 1): 24,
#  ('iphon', 1): 648,
#  ('softwar', 1): 24,
#  ('updat', 1): 189,
#  ('fuck', 1): 254,
#  ('phone', 1): 415,
#  ('big', 1): 25,
#  ('time', 1): 111,
#  ('happi', 0): 290,
#  ('us', 0): 45,
#  ('..', 0): 160,
#  ('instap', 0): 59,
#  ('instadaili', 0): 72,
#  ('xperiaz', 0): 24,
#  ('new', 0): 920,
#  ('type', 0): 8,
#  ('c', 0): 13,
#  ('charger', 0): 33,
#  ('cabl', 0): 17,
#  ('uk', 0): 20,
#  ('bout', 0): 3,
#  ('shop', 0): 71,
#  ('listen', 0): 31,
#  ('music', 0): 185,
#  ('justm', 0): 4,
#  ('likeforlik', 0): 19,
#  ('followforfollow', 0): 6,
#  ('photo', 0): 306,
#  ('fun', 0): 199,
#  ('selfi', 0): 160,
#  ('pool', 0): 7,
#  ('water', 0): 24,
#  ('camera', 0): 122,
#  ('picoftheday', 0): 115,
#  ('sun', 0): 62,
#  ('instagood', 0): 239,
#  ('boy', 0): 69,
#  ('outdoor', 0): 15,
#  ('hey', 1): 25,
#  ('make', 1): 87,
#  ('new', 1): 182,
#  ('ipod', 1): 128,
#  ('dont', 1): 19,
#  ('color', 1): 3,
#  ('2inch', 1): 1,
#  ('thinner', 1): 2,
#  ('crash', 1): 32,
#  ('everi', 1): 45,
#  ('five', 1): 3,
#  ('fuckin', 1): 3,
#  ('minit', 1): 1,
#  ('ha', 1): 3,
#  ('heavi', 1): 1,
#  ('machineri', 1): 1,
#  ('need', 1): 77,
#  ('realli', 1): 51,
#  ('drop', 1): 21,
#  ('ball', 1): 4,
#  ('design', 1): 7,
#  ('drinkyourhaterad', 1): 1,
#  ('contempl', 1): 1,
#  ('give', 1): 25,
#  ('bandwagon', 1): 1,
#  ('simpli', 1): 2,
#  ('cellcom', 1): 1,
#  ('android', 1): 49,
#  ('depress', 1): 5,
#  ('idontwantto', 1): 1,
#  ('anoth', 0): 31,
#  ('crazi', 0): 30,
#  ('purchas', 0): 10,
#  ('lol', 0): 98,
#  ('theori', 0): 1,
#  ('work', 0): 168,
#  ('hard', 0): 35,
#  ('play', 0): 56,
#  ('ipad', 0): 252,
#  ('appl', 0): 1395,
#  ('batteri', 1): 55,
#  ('pain', 1): 4,
#  ('charg', 1): 60,
#  ('overnight', 1): 2,
#  ('lunchtim', 1): 1,
#  ('dead', 1): 14,
#  ('hateorang', 1): 2,
#  ('deepellum', 0): 1,
#  ('toward', 0): 2,
#  ('downtown', 0): 4,
#  ('dalla', 0): 1,
#  ('bigd', 0): 1,
#  ('saturday', 0): 40,
#  ('rx100m3', 0): 1,
#  ('summer', 0): 113,
#  ('urban', 0): 8,
#  ('like', 0): 377,
#  ('share', 0): 43,
#  ('want', 0): 75,
#  ('3d', 0): 15,
#  ('phone', 0): 551,
#  ('iphonesia', 0): 132,
#  ('instagram', 0): 347,
#  ('photooftheday', 0): 184,
#  ('tweegram', 0): 50,
#  ('reason', 1): 26,
#  ('one', 1): 102,
#  ('suck', 1): 102,
#  ('truth', 1): 3,
#  ('truthbetold', 1): 1,
#  ('agre', 1): 8,
#  ('fact', 1): 17,
#  ('realitycheck', 1): 1,
#  ('blackberrypic.twitter.com/zpggd7cazn', 1): 1,
#  ('store', 1): 41,
#  ('gunna', 1): 3,
#  ('5c', 1): 5,
#  ('screen', 1): 48,
#  ('monday', 1): 6,
#  ('ur', 1): 10,
#  ('fuckingpiss', 1): 1,
#  ('art', 0): 105,
#  ('easter', 0): 10,
#  ('dear', 0): 17,
#  ('friend', 0): 163,
#  ('publish', 0): 1,
#  ('channel', 0): 3,
#  ('design', 0): 47,
#  ('face', 0): 40,
#  ('bunni', 0): 6,
#  ('email', 0): 8,
#  ('png', 0): 1,
#  ('thumbnail', 0): 1,
#  ('mutita.edibleart@gmail.compic.twitter.com', 0): 1,
#  ('7jhwphfbgt', 0): 1,
#  ('excus', 0): 2,
#  ('waiter', 0): 1,
#  ('seem', 0): 3,
#  ('pie', 0): 26,
#  ('soup', 0): 5,
#  ('wife', 0): 12,
#  ('bake', 0): 4,
#  ("i'v", 1): 56,
#  ('four', 1): 4,
#  ('day', 1): 76,
#  ('button', 1): 20,
#  ('back', 1): 67,
#  ('broke', 1): 22,
#  ('...', 1): 232,
#  ('accident', 1): 4,
#  ('hit', 1): 7,
#  ('goe', 1): 12,
#  ('complet', 1): 19,
#  ('black', 1): 5,
#  ('keep', 1): 28,
#  ('get', 1): 204,
#  ('text', 1): 45,
#  ("can't", 1): 113,
#  ('check', 1): 9,
#  ('6thiphon', 1): 1,
#  ('time', 0): 134,
#  ('wallpap', 0): 22,
#  ('wall', 0): 7,
#  ('screen', 0): 53,
#  ('galaxi', 0): 328,
#  ('samsung', 0): 1167,
#  ('app', 0): 212,
#  ('1.05', 0): 1,
#  ('billion', 0): 1,
#  ('3', 0): 180,
#  ('patent', 0): 8,
#  ('prior', 0): 1,
#  ('300', 0): 3,
#  ('million', 0): 11,
#  ('troll', 0): 4,
#  ('parti', 0): 42,
#  ('mess', 1): 16,
#  ('done', 1): 13,
#  ('noth', 1): 22,
#  ('myloss', 1): 1,
#  ('touch', 1): 8,
#  ('frozen', 1): 3,
#  ('logo', 1): 5,
#  ('start', 1): 34,
#  ('lose', 1): 16,
#  ("demi'", 1): 1,
#  ('music', 1): 55,
#  ('pic', 1): 7,
#  ('kill', 1): 14,
#  ('someon', 1): 22,
#  ('soangri', 1): 2,
#  ('hateappl', 1): 46,
#  ('flower', 0): 49,
#  ('green', 0): 39,
#  ('diamond', 0): 7,
#  ('pearl', 0): 4,
#  ('4s', 0): 45,
#  ('must', 0): 159,
#  ('watch', 0): 71,
#  ('youtub', 0): 30,
#  ('subscrib', 0): 12,
#  ('daili', 0): 16,
#  ('vlog', 0): 16,
#  ('twitch', 0): 15,
#  ('game', 0): 212,
#  ('ps4', 0): 99,
#  ('xbox', 0): 24,
#  ('io', 0): 170,
#  ('android', 0): 183,
#  ('live', 0): 112,
#  ('laugh', 0): 55,
#  ('life', 0): 301,
#  ('food', 0): 58,
#  ('philippin', 0): 3,
#  ('instago', 0): 34,
#  ('instahub', 0): 28,
#  ('ch', 0): 1,
#  ('cannon', 0): 1,
#  ('suewe', 0): 2,
#  ('friendship', 0): 11,
#  ('americanbulli', 0): 2,
#  ('dog', 0): 68,
#  ('piggi', 0): 1,
#  ('famili', 0): 133,
#  ('southerncharm', 0): 1,
#  ('americanidol', 0): 1,
#  ('goal', 0): 14,
#  ('bestfriend', 0): 26,
#  ('pitbul', 0): 6,
#  ('iphonex', 0): 162,
#  ('onelov', 0): 4,
#  ('countri', 0): 6,
#  ('muscl', 0): 4,
#  ('nfl', 0): 3,
#  ('worldwid', 0): 3,
#  ('america', 0): 11,
#  ('bigboy', 0): 3,
#  ('thislif', 0): 1,
#  ('tmz', 0): 3,
#  ('wild', 0): 8,
#  ('hoggpic.twitter.com/1mn5ogpi2c', 0): 1,
#  ('mimmo.', 0): 6,
#  ('feb', 0): 3,
#  ('2016', 0): 36,
#  ('taken', 0): 29,
#  ('rx100', 0): 6,
#  ('direzionevertical', 0): 1,
#  ('sunset', 0): 61,
#  ('sky', 0): 53,
#  ('beauti', 0): 288,
#  ('pic.twitter.com/cxifijj54g', 0): 1,
#  ('sister', 0): 30,
#  ('bought', 0): 43,
#  ('earli', 0): 32,
#  ('b-day', 0): 1,
#  ('gift', 0): 143,
#  ('s4', 0): 68,
#  ('receiv', 0): 11,
#  ('note', 0): 151,
#  ('2', 0): 192,
#  ('mani', 0): 11,
#  ('market', 0): 12,
#  ('pipelin', 0): 1,
#  ('delet', 1): 74,
#  ('individu', 1): 2,
#  ('song', 1): 23,
#  ('itun', 1): 134,
#  ('everybodi', 1): 2,
#  ('freak', 1): 15,
#  ('io', 1): 171,
#  ('7', 1): 77,
#  ("i'm", 1): 108,
#  ('like', 1): 108,
#  ('duuud', 1): 1,
#  ('window', 1): 28,
#  ('advanc', 1): 4,
#  ('custom', 1): 26,
#  ('5s', 1): 7,
#  ('stand', 1): 7,
#  ("sirri'i", 1): 1,
#  ('bad', 1): 14,
#  ('c', 1): 4,
#  ('cheap', 1): 3,
#  ('re', 1): 1,
#  ('camera', 1): 15,
#  ('tech', 1): 14,
#  ('bull', 0): 5,
#  ('instas', 0): 5,
#  ('leg', 0): 6,
#  ('lightskin', 0): 1,
#  ('curlyhair', 0): 2,
#  ('bellypierc', 0): 1,
#  ('smile', 0): 232,
#  ('potd', 0): 12,
#  ('din', 0): 1,
#  ('’', 0): 108,
#  ('creat', 0): 8,
#  ('let', 0): 25,
#  ('destroy', 0): 3,
#  ('candid', 0): 5,
#  ('sunday', 0): 55,
#  ('sundayvib', 0): 2,
#  ('alway', 0): 42,
#  ('eye', 0): 25,
#  ('ootd', 0): 21,
#  ('fashion', 0): 107,
#  ('blackandwhit', 0): 22,
#  ('poser', 0): 4,
#  ('attitud', 0): 1,
#  ('lifeisgood', 0): 1,
#  ('mylook', 0): 1,
#  ('mylif', 0): 7,
#  ('photoeveryday', 0): 1,
#  ('lookoftheday', 0): 4,
#  ('latepost', 0): 4,
#  ('mylifepic.twitter.com/mmhcqyad9b', 0): 1,
#  ('film', 0): 26,
#  ('set', 0): 18,
#  ('build', 0): 5,
#  ('time-laps', 0): 1,
#  ('. .', 0): 16,
#  ('video', 0): 57,
#  ('produc', 0): 14,
#  ('videoproduct', 0): 5,
#  ('follow', 0): 855,
#  ('commerci', 0): 8,
#  ('actor', 0): 7,
#  ('actress', 0): 6,
#  ('hollywood', 0): 4,
#  ('losangel', 0): 7,
#  ('movi', 0): 27,
#  ('act', 0): 6,
#  ('startup', 0): 5,
#  ('startupvideo', 0): 2,
#  ('shotoniphonpic.twitter.com/94eceiain', 0): 1,
#  ('cupcak', 0): 7,
#  ('pink', 0): 80,
#  ('sweet', 0): 80,
#  ('cherri', 0): 5,
#  ('eeee', 0): 1,
#  ('sexi', 0): 37,
#  ('ladi', 0): 10,
#  ('acquisto', 0): 1,
#  ('del', 0): 1,
#  ('week', 0): 39,
#  ('end', 0): 21,
#  ('8', 0): 92,
#  ('8p', 0): 8,
#  ('lu', 0): 9,
#  ('gril', 0): 3,
#  ('moment', 0): 39,
#  ('itali', 0): 23,
#  ('majest', 0): 2,
#  ('see', 0): 46,
#  ('differ', 0): 12,
#  ('photographi', 0): 154,
#  ('natur', 0): 82,
#  ('landscap', 0): 15,
#  ('forest', 0): 3,
#  ('hidden', 0): 2,
#  ('clear', 0): 6,
#  ('view', 0): 13,
#  ('wood', 0): 4,
#  ('tree', 0): 34,
#  ('travel', 0): 71,
#  ('biker', 0): 1,
#  ('a7', 0): 13,
#  ('ziess', 0): 1,
#  ('instgramhub', 0): 1,
#  ('googl', 1): 13,
#  ('cut', 1): 12,
#  ('program', 1): 9,
#  ('ahhh', 0): 7,
#  ('look', 0): 131,
#  ('got', 0): 203,
#  ('christma', 0): 114,
#  ('<3', 0): 48,
#  ('girl', 0): 206,
#  ('instacool', 0): 22,
#  ('20like', 0): 3,
#  ('bitcoinboy', 0): 1,
#  ('ipod', 0): 79,
#  ('free', 0): 102,
#  ('kansa', 0): 2,
#  ('georgia', 0): 3,
#  ('antoin', 0): 3,
#  ('check', 0): 58,
#  ('106', 0): 1,
#  ('ent', 0): 1,
#  ('appstor', 0): 27,
#  ('joy', 0): 36,
#  ('peac', 0): 31,
#  ('reflect', 0): 12,
#  ('rememb', 0): 9,
#  ('cloud', 0): 25,
#  ('cloudhub', 0): 5,
#  ('skyhub', 0): 5,
#  ('gr', 0): 8,
#  ('babi', 0): 145,
#  ('babyboy', 0): 2,
#  ('muesli', 0): 2,
#  ('hedgehog', 0): 1,
#  ('pet', 0): 26,
#  ('7', 0): 111,
#  ('inbox', 0): 2,
#  ('letter', 0): 3,
#  ('editor', 0): 1,
#  ('news', 0): 109,
#  ('health', 0): 15,
#  ('fail', 0): 15,
#  ('tech', 0): 79,
#  ('funni', 0): 61,
#  ('lolpic.twitter.com/ik1rhumovz', 0): 1,
#  ('thinner', 0): 1,
#  ('faster', 0): 4,
#  ('amaz', 0): 171,
#  ('hate', 0): 26,
#  ('get', 0): 173,
#  ('one', 0): 118,
#  ('ye', 0): 44,
#  ('tablet', 0): 54,
#  ('person', 0): 14,
#  ('use', 0): 80,
#  ('sens', 0): 3,
#  ('im', 0): 23,
#  ('fan', 0): 26,
#  ('think', 0): 40,
#  ('quit', 0): 6,
#  ('gd', 0): 2,
#  ('product', 0): 54,
#  ('black', 0): 88,
#  ('friday', 0): 57,
#  ('call', 0): 30,
#  ('‘', 0): 16,
#  ('serious', 1): 33,
#  ('afraid', 1): 1,
#  ('profit', 1): 4,
#  ('go', 1): 105,
#  ('els', 1): 12,
#  ('’', 1): 27,
#  ('pocket', 1): 1,
#  ('charger', 1): 92,
#  ('“', 1): 20,
#  ('”', 1): 19,
#  ('18', 1): 3,
#  ('po', 1): 5,
#  ('month', 1): 37,
#  ('good', 1): 31,
#  ('job', 1): 30,
#  ('actual', 1): 23,
#  ('£', 1): 16,
#  ('209', 1): 1,
#  ('replac', 1): 20,
#  ("that'", 1): 20,
#  ('still', 1): 67,
#  ('basic', 1): 5,
#  ('rt', 1): 23,
#  ('droid', 1): 10,
#  ('wait', 0): 57,
#  ('doubl', 0): 5,
#  ('saw', 0): 6,
#  (';]', 0): 1,
#  ('alyssa', 0): 1,
#  ('4h', 0): 1,
#  ('cool', 0): 105,
#  ('pictur', 0): 57,
#  ('l', 0): 18,
#  ('cycl', 0): 2,
#  ('complet', 0): 15,
#  ('froot', 0): 1,
#  ('run', 0): 25,
#  ('beach', 0): 49,
#  ('sport', 0): 16,
#  ("that'", 0): 17,
#  ('bit', 0): 13,
#  ('hypocrit', 0): 1,
#  ('hashtag', 0): 16,
#  ('yet', 0): 10,
#  ('quiver', 0): 1,
#  ('anticip', 0): 1,
#  ('arriv', 0): 43,
#  ('gain', 0): 309,
#  ('rt', 0): 398,
#  ('back', 0): 229,
#  ('everyon', 0): 170,
#  ('sougofollow', 0): 165,
#  ('ff', 0): 34,
#  ('i7si', 0): 1,
#  ('geometri', 0): 1,
#  ('. . . . . . . . . . . . . . .', 0): 4,
#  ('iphoneographi', 0): 52,
#  ('iphoneonli', 0): 76,
#  ('2018', 0): 44,
#  ('streetphotographi', 0): 9,
#  ('iphonephotographi', 0): 14,
#  ('mobilephotographi', 0): 5,
#  ('mobil', 0): 78,
#  ('color', 0): 46,
#  ('bright', 0): 17,
#  ('user', 0): 26,
#  ('less', 0): 14,
#  ('random', 0): 37,
#  ('instamood', 0): 95,
#  ('loljk', 0): 1,
#  ('shine', 0): 10,
#  ('wine', 0): 10,
#  ('copenhagen', 0): 5,
#  ('creativ', 0): 18,
#  ('compos', 0): 5,
#  ('denmark', 0): 7,
#  ('f4f', 0): 18,
#  ('hot', 0): 55,
#  ('icon', 0): 8,
#  ('keepthefaith', 0): 5,
#  ('l4l', 0): 18,
#  ('mariajensen', 0): 5,
#  ('origin', 0): 14,
#  ('pop', 0): 19,
#  ('red', 0): 67,
#  ('rock', 0): 19,
#  ('soul', 0): 12,
#  ('singer', 0): 14,
#  ('songwrit', 0): 8,
#  ('song', 0): 36,
#  ('univers', 0): 12,
#  ('warnerpic.twitter.com/gbeusyed5m', 0): 1,
#  ('wed', 0): 26,
#  ('dvd', 0): 4,
#  ('thought', 0): 14,
#  ("i'd", 0): 10,
#  ('lost', 0): 15,
#  ('day', 0): 345,
#  ('meliiecandi', 0): 1,
#  ('ipadmini', 0): 20,
#  ('sold', 0): 6,
#  ('instamo', 0): 10,
#  ('planeteig', 0): 1,
#  ('01', 0): 2,
#  ('feel', 0): 53,
#  ('broken', 0): 7,
#  ("phone'", 0): 1,
#  ('replac', 0): 20,
#  ('pic.twitter.com/ygsuke2c', 0): 1,
#  ('light', 0): 41,
#  ('pleas', 0): 23,
#  ('. . . . . .', 0): 7,
#  ('lamp', 0): 2,
#  ('pekanbaru', 0): 1,
#  ('riau', 0): 1,
#  ('indonesia', 0): 16,
#  ('a6000', 0): 31,
#  ('sonya', 0): 24,
#  ('6000', 0): 27,
#  ('acquisit', 0): 2,
#  ('5s', 0): 43,
#  ('gold', 0): 48,
#  ('brussel', 0): 3,
#  ('havent', 1): 1,
#  ('reset', 1): 16,
#  ('work', 1): 137,
#  ('sorri', 1): 14,
#  ('incept', 0): 1,
#  ('white', 0): 109,
#  ('tea', 0): 12,
#  ('chill', 0): 30,
#  ('carcasa', 0): 1,
#  ('cover', 0): 63,
#  ('para', 0): 1,
#  ('grandprim', 0): 1,
#  ('felizdomingo', 0): 1,
#  ('samsunggalaxi', 0): 30,
#  ('g530', 0): 1,
#  ('felizlun', 0): 1,
#  ('felizsemana', 0): 1,
#  ('2oct', 0): 1,
#  ('3oct', 0): 1,
#  ('felizmartespic.twitter.com/xtldsjwpz9', 0): 1,
#  ("apple'", 1): 15,
#  ('mighti', 1): 1,
#  ('mous', 1): 3,
#  ('came', 1): 9,
#  ('2', 1): 63,
#  ('lithium', 1): 2,
#  ("aa'", 1): 2,
#  ('magic', 1): 3,
#  ('come', 1): 30,
#  ('alkalin', 1): 1,
#  ('followsunday', 0): 30,
#  ('followback', 0): 52,
#  ('teamfollowback', 0): 32,
#  ('retweet', 0): 61,
#  ('keep', 0): 57,
#  ('ya', 0): 42,
#  ('thing', 0): 70,
#  ('tumbl', 0): 1,
#  ('dryer', 0): 1,
#  ('4', 0): 179,
#  ('month', 0): 19,
#  ('alreadi', 0): 13,
#  ('problem', 0): 14,
#  ('occur', 0): 1,
#  ('iwant', 0): 2,
#  ('issu', 0): 8,
#  ('resolv', 0): 1,
#  ('abl', 0): 7,
#  ('return', 0): 4,
#  ('a7sll', 0): 1,
#  ('7s2', 0): 1,
#  ('throwback', 0): 2,
#  ('shoot', 0): 24,
#  ('bluri', 0): 1,
#  ('pic', 0): 55,
#  ('pic.twitter.com/3btew6b4kx', 0): 1,
#  ('call', 1): 23,
#  ('put', 1): 37,
#  ('absurd', 1): 2,
#  ('price', 1): 8,
#  ('devic', 1): 24,
#  ('commonwealth', 0): 2,
#  ('skye', 0): 1,
#  ('nicolson', 0): 1,
#  ('win', 0): 34,
#  ('box', 0): 13,
#  ('memori', 0): 16,
#  ('dead', 0): 5,
#  ('brother', 0): 23,
#  ('–', 0): 23,
#  ('adapt', 0): 3,
#  ('galatasaray', 0): 1,
#  ('iherbord', 0): 1,
#  ('presidenttrump', 0): 1,
#  ('oh', 1): 20,
#  ('dear', 1): 30,
#  ('joy', 1): 2,
#  ('5', 1): 61,
#  ('comment', 1): 2,
#  ('lip', 1): 1,
#  ('win', 1): 8,
#  ('getalif', 1): 1,
#  ('tecshit', 1): 1,
#  ('enjoy', 0): 44,
#  ('ps3', 0): 50,
#  ('tombraid', 0): 1,
#  ('laracroft', 0): 1,
#  ('playstat', 0): 70,
#  ('gamer', 0): 44,
#  ('hunger', 0): 3,
#  ('simpson', 0): 3,
#  ('thehungergam', 0): 1,
#  ('2012', 0): 19,
#  ('someth', 0): 17,
#  ('wrong', 0): 5,
#  ('right', 0): 27,
#  ('today', 0): 212,
#  ('make', 0): 157,
#  ('item', 0): 4,
#  ('recommend', 0): 4,
#  ('earphon', 0): 12,
#  ('earpod', 0): 2,
#  ('lifestyl', 0): 23,
#  ('fuckyou', 1): 66,
#  ('never', 1): 55,
#  ('end', 1): 9,
#  ('bug', 1): 10,
#  ('buck', 1): 6,
#  ('phone.how', 1): 1,
#  ('littl', 1): 7,
#  ('qualiti', 1): 4,
#  ('anotherangrycustom', 1): 1,
#  ('girlfriend', 0): 12,
#  ('year', 0): 93,
#  ('gf', 0): 2,
#  ('bf', 0): 7,
#  ('card', 0): 14,
#  ('z', 0): 6,
#  ('soppi', 0): 1,
#  ('birthday', 0): 155,
#  ('present', 0): 65,
#  ('mom', 0): 35,
#  ('macbookpro', 0): 39,
#  ('macbook', 0): 75,
#  ('stockholm', 0): 3,
#  ('sweden', 0): 10,
#  ('comput', 0): 33,
#  ('quot', 0): 56,
#  ('wisdom', 0): 9,
#  ('word', 0): 25,
#  ('tweetgram', 0): 11,
#  ('applaud', 0): 1,
#  ('sheffield', 0): 1,
#  ('store', 0): 47,
#  ('custom', 0): 51,
#  ('servic', 0): 24,
#  ('great', 0): 71,
#  ('qualiti', 0): 9,
#  ('repair', 0): 11,
#  ('done', 0): 25,
#  ('hour', 0): 27,
#  ('lost', 1): 40,
#  ('everyth', 1): 48,
#  ('due', 1): 7,
#  ('recoveri', 1): 6,
#  ('mode', 1): 8,
#  ('hater', 1): 2,
#  ('yousuck', 1): 9,
#  ('briantong', 1): 1,
#  ('easytotalk', 1): 1,
#  ('producesometh', 1): 1,
#  ('usa', 1): 3,
#  ('compani', 1): 25,
#  ('korean', 1): 1,
#  ('samsung', 1): 109,
#  ('fan', 1): 8,
#  ('loser', 1): 3,
#  ('thank', 1): 72,
#  ('server', 1): 4,
#  ('soni', 1): 78,
#  ('dumb', 1): 9,
#  ('schedul', 1): 3,
#  ('mainten', 1): 2,
#  ('today', 1): 28,
#  ('model', 0): 37,
#  ('byhilalak', 0): 1,
#  ('urbanear', 0): 1,
#  ('handmad', 0): 5,
#  ('hayatinarenkkat', 0): 1,
#  ('itun', 0): 64,
#  ('vicio', 0): 4,
#  ('nellyfurtado', 0): 1,
#  ('nelstar', 0): 1,
#  ('playingnow', 0): 1,
#  ('diva', 0): 4,
#  ('cd', 0): 6,
#  ('featur', 0): 23,
#  ('yey', 0): 8,
#  ('sonyxperiaz', 0): 4,
#  ('bless', 0): 36,
#  ('feliz', 0): 6,
#  ('sábado', 0): 1,
#  ('con', 0): 8,
#  ('café', 0): 2,
#  ('coffe', 0): 34,
#  ('pantri', 0): 2,
#  ('dreami', 0): 1,
#  ('effect', 0): 11,
#  ('straight', 0): 2,
#  ('impress', 0): 9,
#  ('spring', 0): 34,
#  ('blossom', 0): 5,
#  ('finallli', 0): 1,
#  ('galaxynot', 0): 28,
#  ('awsom', 0): 5,
#  ('beamman', 0): 1,
#  ('best', 0): 121,
#  ('special', 0): 13,
#  ('valentin', 0): 29,
#  ('36', 0): 1,
#  ('eri', 0): 6,
#  ('pa', 0): 5,
#  ('car', 0): 36,
#  ('sign', 0): 9,
#  ('ilovey', 0): 3,
#  ('lunch', 0): 11,
#  ('park', 0): 13,
#  ('carrot', 0): 6,
#  ('banana', 0): 15,
#  ('autumn', 0): 9,
#  ('leav', 0): 15,
#  ('iphone--th', 0): 1,
#  ('confess', 0): 3,
#  ('spend', 0): 8,
#  ('faith', 0): 5,
#  ('need', 0): 60,
#  ('sin', 0): 2,
#  ('much', 0): 66,
#  ('32', 0): 4,
#  ('p', 0): 14,
#  ('book', 0): 21,
#  ('flickr', 0): 1,
#  ('want', 1): 90,
#  ('say', 1): 65,
#  ('u', 1): 44,
#  ('took', 1): 25,
#  ('3', 1): 63,
#  ('hour', 1): 82,
#  ('download', 1): 50,
#  ('hate', 1): 128,
#  ('westcoast', 0): 1,
#  ('huntington', 0): 1,
#  ('ad', 0): 20,
#  ('losin', 1): 1,
#  ('recept', 1): 3,
#  ('got', 1): 77,
#  ('6', 1): 54,
#  ('n', 1): 4,
#  ('miss', 1): 9,
#  ('last', 1): 39,
#  ('30', 1): 8,
#  ('min', 1): 10,
#  ('come', 0): 75,
#  ('jump', 0): 6,
#  ('rid', 0): 3,
#  ('absolut', 0): 7,
#  ('tmobil', 0): 13,
#  ('tast', 0): 2,
#  ('frank', 0): 5,
#  ('ocean', 0): 5,
#  ('annoy', 1): 35,
#  ('finish', 1): 3,
#  ('level', 1): 4,
#  ("where'", 1): 3,
#  ('water', 1): 4,
#  ('buy', 1): 55,
#  ('full', 1): 7,
#  ('version', 1): 16,
#  ('..', 1): 103,
#  ('noth', 0): 14,
#  ('wear', 0): 5,
#  ('import', 0): 6,
#  ('mood', 0): 17,
#  ('boss', 0): 9,
#  ('blog', 0): 23,
#  ('style', 0): 62,
#  ('wcw', 0): 2,
#  ('wce', 0): 1,
#  ('bestoftheday', 0): 23,
#  ('pretti', 0): 68,
#  ('babe', 0): 15,
#  ('wednesday', 0): 6,
#  ('funpic.twitter.com/ggnuvxbv42', 0): 1,
#  ('send', 1): 24,
#  ('turn', 1): 26,
#  ('imessag', 1): 21,
#  ('fanta', 0): 3,
#  ('delish', 0): 1,
#  ('sundayfunday', 0): 3,
#  ('heal', 0): 1,
#  ('sleep', 0): 29,
#  ('lap', 0): 3,
#  ('babygirl', 0): 3,
#  ('popular', 0): 26,
#  ('5', 0): 145,
#  ('loverli', 0): 1,
#  ('tweet', 0): 29,
#  ('rabbitsofinstagram', 0): 4,
#  ('bunniesofinstagram', 0): 4,
#  ('rabbit', 0): 6,
#  ('hop', 0): 7,
#  ('bounc', 0): 4,
#  ('charli', 0): 6,
#  ('houserabbit', 0): 4,
#  ('bunnylov', 0): 4,
#  ('rabbitsofig', 0): 4,
#  ('shotoniphon', 0): 23,
#  ('7plu', 0): 27,
#  ('photograph', 0): 40,
#  ('chuck', 0): 5,
#  ('charl', 0): 2,
#  ("valentine'", 0): 17,
#  ('lucien', 0): 1,
#  ('swarovski', 0): 2,
#  ('crystal', 0): 3,
#  ('vegan', 0): 7,
#  ('glutenfre', 0): 3,
#  ('silli', 0): 7,
#  ('salli', 0): 1,
#  ('diner', 0): 3,
#  ('technolog', 1): 8,
#  ('sync', 1): 32,
#  ('hear', 1): 5,
#  ('8', 1): 30,
#  ('second', 1): 12,
#  ('mmlp', 1): 1,
#  ('fml', 1): 16,
#  ('candi', 0): 10,
#  ('beati', 0): 3,
#  ('good', 0): 149,
#  ('nice', 0): 80,
#  ('fo', 0): 2,
#  ('hand', 0): 20,
#  ('10', 0): 41,
#  ('spacegray', 0): 4,
#  ('256gb', 0): 12,
#  ('pic.twitter.com/ogo7gkeopw', 0): 1,
#  ('unpack', 0): 1,
#  ('z5', 0): 1,
#  ('compact', 0): 2,
#  ('realli', 0): 34,
#  ('first', 0): 63,
#  ('progress', 1): 2,
#  ('bar', 1): 5,
#  ('1', 1): 32,
#  ('car', 1): 5,
#  ('key', 1): 5,
#  ('long', 1): 15,
#  ('anoth', 1): 40,
#  ('cold', 1): 2,
#  ('boot', 1): 6,
#  ('fear', 1): 1,
#  ("it'll", 1): 3,
#  ('. .', 1): 7,
#  ('siri', 0): 30,
#  ('doesnt', 0): 2,
#  ('understand', 0): 3,
#  ('command', 0): 1,
#  ('nephew', 0): 4,
#  ('all_shot', 0): 3,
#  ('iger', 0): 101,
#  ('endless', 0): 3,
#  ('photoofthaday', 0): 1,
#  ('liter', 1): 14,
#  ('cri', 1): 9,
#  ('contact', 1): 30,
#  ('wonder', 0): 20,
#  ('avail', 0): 30,
#  ('b', 0): 24,
#  ('compar', 0): 6,
#  ("apple'", 0): 10,
#  ('¡', 0): 3,
#  ('al', 0): 11,
#  ('fiiin', 0): 1,
#  ('laptop', 0): 52,
#  ('vaio', 0): 17,
#  ('minni', 0): 2,
#  ('inlov', 0): 15,
#  ('blackberri', 0): 24,
#  ('occasion', 0): 1,
#  ('fruit', 0): 29,
#  ('fall', 0): 16,
#  ('worri', 0): 6,
#  ('thou', 0): 1,
#  ('soon', 0): 29,
#  ('usernam', 0): 1,
#  ('：', 0): 1,
#  ('splinkio', 0): 1,
#  ('yosemit', 1): 3,
#  ('steep', 1): 1,
#  ('hill', 1): 2,
#  ('climb', 1): 1,
#  ('mac', 1): 62,
#  ('kernel', 1): 2,
#  ('issu', 1): 11,
#  ('serv', 1): 3,
#  ('well', 1): 39,
#  ('ps3', 1): 17,
#  ('health', 1): 2,
#  ('warn', 1): 7,
#  ('display', 1): 4,
#  ('upon', 1): 3,
#  ('shesh', 0): 1,
#  ('told', 0): 3,
#  ('stop', 0): 10,
#  ('kill', 0): 9,
#  ('mojo', 0): 1,
#  (';p', 0): 3,
#  ...}

# %%
# test the function below
print('This is an example of a positive tweet: \n', train_x[4])
print('\nThis is an example of the processed version of the tweet: \n', process_tweet(train_x[4]))
# Out:
# This is an example of a positive tweet:
#  What amazing service! Apple won't even talk to me about a question I have unless I pay them $19.95 for their stupid support!
#
# This is an example of the processed version of the tweet:
#  ['amaz', 'servic', 'appl', 'even', 'talk', 'question', 'unless', 'pay', '95', 'stupid', 'support']

# %%
# UNQ_C3 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def extract_features(tweet, freqs):
    '''
    Input: 
        tweet: a list of words for one tweet
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
    Output: 
        x: a feature vector of dimension (1,3)
    '''
    # process_tweet tokenizes, stems, and removes stopwords
    word_l = process_tweet(tweet)
    
    # 3 elements in the form of a 1 x 3 vector
    x = np.zeros((1, 3)) 
    
    #bias term is set to 1
    x[0,0] = 1 
    
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # loop through each word in the list of words
    for word in word_l:
#         print(word)
        # increment the word count for the positive label 1
        x[0,1] += freqs.get((word,1.0),0)
        
        # increment the word count for the negative label 0
        x[0,2] += freqs.get((word,0.0),0)
        
    ### END CODE HERE ###
    assert(x.shape == (1, 3))
    return x

# %%
# Check your function

# test 1
# test on training data
tmp1 = extract_features(train_x[4], freqs)
print(tmp1)
# Out:
# amaz
# servic
# appl
# even
# talk
# question
# unless
# pay
# 95
# stupid
# support
# [[1.000e+00 1.469e+03 1.720e+03]]

# %%
# UNQ_C2 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def gradientDescent(x, y, theta, alpha, num_iters):
    '''
    Input:
        x: matrix of features which is (m,n+1)
        y: corresponding labels of the input matrix x, dimensions (m,1)
        theta: weight vector of dimension (n+1,1)
        alpha: learning rate
        num_iters: number of iterations you want to train your model for
    Output:
        J: the final cost
        theta: your final weight vector
    Hint: you might want to print the cost to make sure that it is going down.
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    # get 'm', the number of rows in matrix x
    m = x.shape[0]     
    for i in range(0, num_iters):
        
        # get z, the dot product of x and theta
        z = np.dot(x,theta)
        
        # get the sigmoid of h
        h = sigmoid(z)
        
        # calculate the cost function
        J = -1./m * (np.dot(y.transpose(), np.log(h)) + np.dot((1-y).transpose(),np.log(1-h)))                                                    

        # update the weights theta
        theta = theta - (alpha/m) * np.dot(x.transpose(),(h-y))
        
    ### END CODE HERE ###
#     J = float(J)
    return J, theta

# %%
# %%time
# collect the features 'x' and stack them into a matrix 'X'
X = np.zeros((len(train_x), 3))
for i in range(len(train_x)):
    X[i, :]= extract_features(train_x[i], freqs)

# training labels corresponding to X
Y = train_y

# Apply gradient descent
J, theta = gradientDescent(X, Y, np.zeros((3, 1)), 1e-9, 1500)
print(f"The cost after training is {J:.8f}.")
print(f"The resulting vector of weights is {[round(t, 8) for t in np.squeeze(theta)]}")
# Out:
# Traceback (most recent call last):
#   File "/home/bhaskar/anaconda3/envs/ml/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1312, in time
#     exec(code, glob, local_ns)
#   File "<timed exec>", line 10, in <module>
#   File "<ipython-input-25-ce498b179d52>", line 27, in gradientDescent
#     J = -1./m * (np.dot(y.transpose(), np.log(h)) + np.dot((1-y).transpose(),np.log(1-h)))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/bhaskar/anaconda3/envs/ml/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/bhaskar/anaconda3/envs/ml/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1148, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/home/bhaskar/anaconda3/envs/ml/lib/python3.7/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/home/bhaskar/anaconda3/envs/ml/lib/python3.7/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/home/bhaskar/anaconda3/envs/ml/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/home/bhaskar/anaconda3/envs/ml/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/home/bhaskar/anaconda3/envs/ml/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/home/bhaskar/anaconda3/envs/ml/lib/python3.7/inspect.py", line 733, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# ---------------------------------------------------------------------------

# %%
# %%time
# UNQ_C4 (UNIQUE CELL IDENTIFIER, DO NOT EDIT)
def predict_tweet(tweet, freqs, theta):
    '''
    Input: 
        tweet: a string
        freqs: a dictionary corresponding to the frequencies of each tuple (word, label)
        theta: (3,1) vector of weights
    Output: 
        y_pred: the probability of a tweet being positive or negative
    '''
    ### START CODE HERE (REPLACE INSTANCES OF 'None' with your code) ###
    
    # extract the features of the tweet and store it into x
    x = extract_features(tweet,freqs)
    
    # make the prediction using x and theta
    y_pred = sigmoid(np.dot(x,theta))
    
    ### END CODE HERE ###
    
    return y_pred
# Out:
# CPU times: user 6 µs, sys: 1 µs, total: 7 µs
# Wall time: 10.3 µs

# %%
# Run this cell to test your function
for tweet in ['I am happy', 'I am bad', 'this movie should have been great.', 'great', 'great great', 'great great great', 'great great great great']:
    print( '%s -> %f' % (tweet, predict_tweet(tweet, freqs, theta)))
